# %%
from langchain_community.vectorstores import FAISS
from configparser import ConfigParser

# %%
#load config
config = ConfigParser()
config.read('config.ini')
# Out:
# ['config.ini']

# %%
import csv
from langchain.schema import Document

documents = []
with open("data.csv", encoding="utf-8") as f:
    reader = csv.DictReader(f)
    for row_index, row in enumerate(reader):
        index_id = row.get("index_id", f"row_{row_index}")
        for field_name, field_value in row.items():
            if field_name == "index_id":
                continue  # 跳過 index_id 欄位
            if not field_value.strip():
                continue  # 跳過空內容
            doc = Document(
                page_content=field_value.strip(),
                metadata={
                    "index_id": index_id,
                    "field": field_name,
                }
            )
            documents.append(doc)

print(f"產生了 {len(documents)} 筆欄位級 document。")
print(documents[0])
print(documents[1])
# Out:
# 產生了 2716 筆欄位級 document。
# page_content='泰式打拋醬炒空心菜' metadata={'index_id': '28', 'field': 'name'}
# page_content='泰式打拋醬原先的微酸微辣口感，讓人食慾大開。蒜香、辣椒與空心菜快炒後，清脆的空心菜口味層次豐富，是一道非常下飯的泰式料理。' metadata={'index_id': '28', 'field': 'description'}

# %%
index_map = {}
with open("data.csv", encoding="utf-8") as f:
    reader = csv.DictReader(f)
    for row in reader:
        index_id = row["index_id"]
        index_map[index_id] = row

# %%
from langchain_openai import AzureOpenAIEmbeddings

embedding_model = AzureOpenAIEmbeddings(
    openai_api_version=config["AzureOpenAI"]["VERSION"],
    azure_deployment=config["AzureOpenAI"]["Embedding_DEPLOYMENT_NAME"],
    azure_endpoint=config["AzureOpenAI"]["ENDPOINT"],
    api_key=config["AzureOpenAI"]["KEY"],
)

# %%
# db = FAISS.from_documents(documents, embedding_model)
# 載入 FAISS index
db = FAISS.load_local("faiss_db", embedding_model, "cuisines", allow_dangerous_deserialization=True)

# %%
# 儲存 FAISS index
db.save_local("faiss_db", "cuisines")

# %%
query = "推薦我一個有米酒、食用油、鮮磨黑胡椒的料理"

# %%
result = db.similarity_search_with_score(query, 20)

# %%
# 收集所有檢索結果
saved_results = []

for i, (doc, dist) in enumerate(result):
    index_id = doc.metadata["index_id"]
    field = doc.metadata["field"]
    content = doc.page_content
    original_row = index_map.get(index_id, {})

    result_entry = {
        "Result_Rank": i + 1,
        "Score": round(dist, 4),
        "Matched_Field": field,
        "Field_Content": content,
        "Index_ID": index_id,
        "Name": original_row.get("name", ""),
        "Description": original_row.get("description", ""),
        "Ingredients": original_row.get("ingredients", ""),
        "Instructions": original_row.get("instructions", "")
    }

    saved_results.append(result_entry)

# %%
contexts = []
for i, result in enumerate(saved_results):
    context = f"Result Rank: {result['Result_Rank']}\n"
    context += f"Score: {result['Score']}\n"
    context += f"Matched Field: {result['Matched_Field']}\n"
    context += f"Field Content: {result['Field_Content']}\n"
    context += f"Index ID: {result['Index_ID']}\n"
    context += f"Name: {result['Name']}\n"
    context += f"Description: {result['Description']}\n"
    context += f"Ingredients: {result['Ingredients']}\n"
    context += f"Instructions: {result['Instructions']}\n\n"

    contexts.append(context)

# %%
from langchain_openai import AzureChatOpenAI

llm = AzureChatOpenAI(
    openai_api_version=config["AzureOpenAI"]["VERSION"],
    azure_deployment=config["AzureOpenAI"]["GPT4o_DEPLOYMENT_NAME"],
    azure_endpoint=config["AzureOpenAI"]["ENDPOINT"],
    api_key=config["AzureOpenAI"]["KEY"],
)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains.combine_documents import create_stuff_documents_chain

# 封裝成 List[Document]
documents = [Document(page_content=c) for c in contexts]

# 建立 prompt
prompt = ChatPromptTemplate.from_template(
"""
Answer the following question based only on the provided context,
besides the answer, please also provide a list of comparison, 
just list item, not table.

{context}

Question: {input}
請用繁體中文回答
"""
)

# 建立 chain 並傳入
document_chain = create_stuff_documents_chain(llm, prompt)

llm_result = document_chain.invoke(
    {
        "input": query,
        "context": documents
    }
)

# %%
for result in saved_results:
    print(f"Rank: {result['Result_Rank']}, Score: {result['Score']}")
    print(f"Matched Field: {result['Matched_Field']}")
    print(f"Field Content: {result['Field_Content']}")
    print(f"Index ID: {result['Index_ID']}")
    print(f"Name: {result['Name']}")
    print(f"Description: {result['Description']}")
    print(f"Ingredients: {result['Ingredients']}")
    print(f"Instructions: {result['Instructions']}")
    print("-" * 40)
# Out:
# Rank: 1, Score: 0.8919000029563904
# Matched Field: description
# Field Content: 家中必備涮嘴零食，充滿黑胡椒與八角香氣的毛豆，不論是平常當零嘴或下酒菜都非常推薦
# Index ID: 306
# Name: 蒜香毛豆
# Description: 家中必備涮嘴零食，充滿黑胡椒與八角香氣的毛豆，不論是平常當零嘴或下酒菜都非常推薦
# Ingredients: ['水 1000毫升', '紅辣椒 1根', '毛豆 400公克', '砂糖 10公克', '玫瑰鹽 10公克', '八角粒 5個', '香蒜粒 10公克', '黑胡椒粉 10公克']
# Instructions: ['食材', '毛豆洗淨、辣椒切圈。', '湯鍋裝水，水裡放入八角煮滾，加入1小匙玫瑰鹽和糖煮溶。', '放入毛豆，維持中火煮3-5分鐘。', '取一玻璃盆，毛豆起鍋瀝乾，放入玻璃盆中。', '灑入香蒜粒、紅辣椒、凍頂黑胡椒、1小匙玫瑰鹽與毛豆拌均勻。', '放入冰箱冷藏15分鐘即可食用。']
# ----------------------------------------
# Rank: 2, Score: 0.9271000027656555
# Matched Field: ingredients
# Field Content: ['蒜頭 5顆', '橄欖油 8毫升', '義大利麵 2把', '鹽 適量公克', '鮮磨黑胡椒 5公克', '羅勒葉 適量公克', '宮保辣椒段 5公克']
# Index ID: 835
# Name: 辣炒蒜味義大利麵
# Description: 經典的蒜炒義大利麵結合中式乾辣椒段，激盪出獨特的辛香風味！乾辣椒段帶來微辣與濃郁椒香，搭配蒜香交織，讓橄欖油充分吸收香氣，完美滲透彈牙麵條，使每一口都辛香過癮、香辣夠味。簡單快炒，快速上桌，無論是日常餐點還是聚會料理，都能成為眾人矚目的美味焦點！
# Ingredients: ['蒜頭 5顆', '橄欖油 8毫升', '義大利麵 2把', '鹽 適量公克', '鮮磨黑胡椒 5公克', '羅勒葉 適量公克', '宮保辣椒段 5公克']
# Instructions: ['食材準備', '煮一鍋水將義大利麵煮至半熟，瀝乾水分撈出，以橄欖油拌勻備用。', '蒜頭切片，備用', '熱鍋，放入少許橄欖油，加入蒜片以小火爆香至金黃色，再加入&lt;小磨坊宮保辣椒段&gt;炒出香氣與辣度', '加入義大利麵拌炒均勻，接著加入煮麵水、黑胡椒、鹽煮至湯汁收乾，起鍋前撒上羅勒葉即完成。']
# ----------------------------------------
# Rank: 3, Score: 0.9376999735832214
# Matched Field: ingredients
# Field Content: ['雞高湯 500毫升', '紅甜椒 1顆', '松阪肉 300公克', '青櫛瓜 1條', '庫司米 1盒', '米酒 15毫升', '薑黃粉 3.5公克', '金黃蒜油 7毫升', '匈牙利紅椒 適量公克', '咖哩粉 3.5公克', '玫瑰鹽 5公克', '黑胡椒粒 適量公克', '白胡椒鹽 5公克']
# Index ID: 235
# Name: 減脂松阪庫司香料飯
# Description: 減肥最在意吃得清淡、索然無味，如何能將平淡無味的食材增添風味，是一件很有挑戰的事!庫司米本身沒有調味，如同米飯，因此加入香料後，可以充分吸收香料的風味，使得米的香氣與味型都很有層次感，因此蔬菜與肉類也不需過度調味，便能吃得津津有味囉!
# Ingredients: ['雞高湯 500毫升', '紅甜椒 1顆', '松阪肉 300公克', '青櫛瓜 1條', '庫司米 1盒', '米酒 15毫升', '薑黃粉 3.5公克', '金黃蒜油 7毫升', '匈牙利紅椒 適量公克', '咖哩粉 3.5公克', '玫瑰鹽 5公克', '黑胡椒粒 適量公克', '白胡椒鹽 5公克']
# Instructions: ['松阪豬用米酒、白胡椒鹽、玫瑰鹽醃漬，放回冰箱冰5分鐘。', '櫛瓜、紅甜椒切丁。', '準備可以淹過庫司米的高湯量，將其煮滾後關火，加入庫司米攤平，蓋上蓋子，等待庫司米悶熟後，掀蓋撥鬆。', '松阪豬放入氣炸鍋，轉160度氣炸10分鐘。', '庫司米加入印度咖哩粉、薑黃粉、玫瑰鹽、蒜風味油調味增香，再蓋上蓋子悶5分鐘入味。', '將蔬菜倒入氣炸鍋，轉160度氣炸5分鐘。', '待松阪豬及蔬菜熟成後，將松阪豬切片，與庫司米、蔬菜一同擺盤。', '灑上匈牙利紅椒粉、粗粒黑胡椒即完成。']
# ----------------------------------------
# Rank: 4, Score: 0.9447000026702881
# Matched Field: description
# Field Content: ３步驟快速上桌，夜晚解嘴饞的好夥伴！米血吸飽醬汁精華，入口有嚼勁，尾韻柴魚香氣十足，鹹香鹹香，用來當下酒菜再適合不過！
# Index ID: 677
# Name: 柴魚香滷米血
# Description: ３步驟快速上桌，夜晚解嘴饞的好夥伴！米血吸飽醬汁精華，入口有嚼勁，尾韻柴魚香氣十足，鹹香鹹香，用來當下酒菜再適合不過！
# Ingredients: ['辣椒 2根', '蔥花 適量公克', '米血 350公克', '醬油 1大匙毫升', '金黃蒜油 1大匙毫升', '鰹魚高湯包 1包']
# Instructions: ['食材準備', '米血切塊，辣椒切斜段，蔥切蔥花', '平底鍋中加入金黃蒜油、醬油、辣椒段炒香', '放入米血後，將鰹魚高湯包剪開，內容物倒入鍋中，加入約200ml水', '燉煮收汁到濃稠後加入蔥花即可起鍋']
# ----------------------------------------
# Rank: 5, Score: 0.946399986743927
# Matched Field: description
# Field Content: 滿滿古早味的炒米粉超彈牙，純白胡椒粉不管在香氣、辣度都完全昇華這道料理，喜愛經典台式料理的一定要嘗試！
# Index ID: 390
# Name: 家常古早味炒米粉
# Description: 滿滿古早味的炒米粉超彈牙，純白胡椒粉不管在香氣、辣度都完全昇華這道料理，喜愛經典台式料理的一定要嘗試！
# Ingredients: ['青蔥 1根', '紅蘿蔔 5-10公克', '香菇 6朵', '高麗菜 100公克', '芹菜 些許根', '純米米粉 200公克', '肉絲 200公克', '醬油 5毫升', '黑醋 5毫升', '金黃蔥油 45毫升', '白胡椒粉 1-2公克']
# Instructions: ['食材大集合。', '生香菇切片、高麗菜切塊狀、紅蘿蔔切絲、青蔥切段、芹菜切末。', '米粉一鍋滾水泡軟即可撈起瀝乾備用。', '鍋中加入蔥風味油、青蔥段拌炒，加入肉絲拌炒至變色後', '撒入純白胡椒粉炒香，放入切好的生香菇、高麗菜、紅蘿蔔炒軟。', '加入醬油、水，煮開後加入米粉拌炒至湯汁收乾。', '起鍋前淋上適量蔥風味油與純白胡椒粉拌炒，再加入芹菜末、淋上烏醋即完成。']
# ----------------------------------------
# Rank: 6, Score: 0.9552000164985657
# Matched Field: description
# Field Content: 香辛料經過啤酒與海鮮的拌炒，鮮甜、清香超涮嘴，輕鬆料理超簡單，與好友一起邊喝邊吃最享受！
# Index ID: 575
# Name: 啤酒香草燉海鮮
# Description: 香辛料經過啤酒與海鮮的拌炒，鮮甜、清香超涮嘴，輕鬆料理超簡單，與好友一起邊喝邊吃最享受！
# Ingredients: ['奶油 20公克', '蔥花 適量公克', '檸檬 1/2顆', '碎花生 10公克', '蛤蜊 300公克', '草蝦 10尾', '透抽 300公克', '啤酒 200毫升', '金黃蒜油 5毫升', '玫瑰鹽 適量公克', '百搭香草 適量公克']
# Instructions: ['食材大集合。', '蛤蜊泡水吐沙、檸檬四開、下酒花生敲碎、透抽切圈', '鍋中倒入少許金黃蒜油，放入透抽煎香', '放入蝦子、蛤蜊，倒入啤酒，煮至蛤蜊全開', '加入奶油後撒入玫瑰鹽、百搭香草，放入檸檬、蔥花', '起鍋後撒上花生碎即完成']
# ----------------------------------------
# Rank: 7, Score: 0.9653000235557556
# Matched Field: name
# Field Content: 燒烤三杯杏鮑菇&米血
# Index ID: 261
# Name: 燒烤三杯杏鮑菇&米血
# Description: 燒烤後的杏鮑菇多汁脆嫩，米血Q嫩滑順！食材帶出的鮮甜與富有傳統麻油與甘甜醇香的醬汁充分融合，一口咬下肉汁迸發香氣四溢，醬香厚韻十分下飯！
# Ingredients: ['水 50毫升', '杏鮑菇 100-150公克', '九層塔 適量公克', '米血 300公克', '砂糖 7公克', '三杯雞調味料 50公克']
# Instructions: ['杏鮑菇洗淨切塊', '米血切塊放置烤皿中', '小磨坊三杯雞調理粉、水、糖調勻', '將醬汁加入烤皿內與食材攪拌，再以錫箔紙包裹烤皿後放入烤箱', '烤箱設定上下火200度，時間20分鐘', '打開錫箔紙，加入九層塔攪拌增添風味即可完成']
# ----------------------------------------
# Rank: 8, Score: 0.9702000021934509
# Matched Field: description
# Field Content: 清脆彩椒與滑嫩肉絲讓口感更加豐富，清香黑胡椒粉增加香氣及風味，在家料理美味又簡單！
# Index ID: 391
# Name: 家常彩椒肉絲
# Description: 清脆彩椒與滑嫩肉絲讓口感更加豐富，清香黑胡椒粉增加香氣及風味，在家料理美味又簡單！
# Ingredients: ['水 50毫升', '辣椒 1/2根', '黃甜椒 1/2顆', '紅甜椒 1/2顆', '青椒 1/2顆', '豬肉絲 200公克', '砂糖 1-2公克', '太白粉 少許公克', '醬油膏 7公克', '金黃蒜油 7毫升', '香蒜粒 適量公克', '黑胡椒粉 1-2公克']
# Instructions: ['食材大集合。', '青、紅、黃椒切條狀泡水保持清脆，辣椒切片。', '豬肉絲用太白粉抓醃更滑嫩，入滾水稍微汆燙撈起備用。', '起鍋加入蒜風味油、辣椒炒香與清香黑胡椒粉炒出底味。', '加入少許清水、醬油膏、糖拌勻後加入彩椒炒至微軟狀。', '加入燙過的豬肉絲拌炒至湯汁收乾', '撒入清香黑胡椒粉與香蒜粒即可起鍋盛盤。']
# ----------------------------------------
# Rank: 9, Score: 0.9718000292778015
# Matched Field: name
# Field Content: 蒜油白酒蛤蠣義大利麵
# Index ID: 533
# Name: 蒜油白酒蛤蠣義大利麵
# Description: 拌炒義大利麵的過程中，加入金黃蒜油達到「乳化」效果，使洋蔥與蛤蠣釋出的鮮甜與蒜油融合在一起，並附著於麵體上，使麵體均勻油亮，口感不油膩，同時帶有蒜香。
# Ingredients: ['洋蔥 1/4顆', '小番茄 3顆', '九層塔 10公克', '義大利麵 1把', '蛤蜊 50公克', '白酒 45毫升', '金黃蒜油 45毫升', '洋香菜葉 適量公克', '玫瑰鹽 5公克', '鮮磨黑胡椒 適量公克']
# Instructions: ['洋蔥切絲、番茄對切、蛤蠣吐沙20分鐘。', '煮一鍋滾水，下義大利麵，再灑一點玫瑰鹽，煮七分鐘。', '義大利麵起鍋後，淋1大匙金黃蒜油拌勻，避免麵體互相沾黏。', '小火熱平底鍋，淋1大匙金黃蒜油，再下洋蔥，轉中小火炒軟洋蔥。', '下蛤蠣一起拌炒後，再淋白酒並蓋上鍋蓋悶熟蛤蠣。', '開蓋後，確認蛤蠣均打開，即可下義大利麵一起拌炒，再灑玫瑰鹽、鮮磨黑胡椒調味。', '起鍋前，下九層塔快速拌炒不焦黑，淋1大匙金黃蒜油後，即可起鍋擺盤。', '擺盤時，以小番茄和洋香菜葉裝飾成品。']
# ----------------------------------------
# Rank: 10, Score: 0.9758999943733215
# Matched Field: name
# Field Content: 香料鮮魚排佐荳蔻白花菜泥
# Index ID: 314
# Name: 香料鮮魚排佐荳蔻白花菜泥
# Description: 以義大利香料作為基底調味香辛料，再加入適合海鮮的百里香葉、增色的薑黃粉、帶香的匈牙利紅椒粉，調和作為醃製並予以鯛魚風味的香辛料；並以白花葉菜泥作為搭配，搭配性的泥狀菜餚，不需賦與太多風味，僅須透過荳蔻粉提味的動作帶出白花椰菜本身的鮮甜味，玫瑰鹽和黑胡椒調味即可。
# Ingredients: ['奶油 7公克', '牛奶 100毫升', '白花椰菜 200-300公克', '橄欖油 60毫升', '九層塔 5公克', '鯛魚片 200-250公克', '薑黃粉 10公克', '匈牙利紅椒 5公克', '玫瑰鹽 2公克', '鮮磨黑胡椒 2公克', '精選月桂葉 2片', '義大利香料 5公克', '百搭香草 5公克', '百里香葉 5公克', '荳蔻粉 5公克']
# Instructions: ['白花椰菜切碎。', '以奶油、荳蔻粉、牛奶拌炒白花椰菜。', '白花菜用牛奶軟化後，再以玫瑰鹽、黑胡椒碎調味，烹煮5分鐘。', '將百里香葉、匈牙利紅椒粉、薑黃粉、義大利香料、百搭香草調和後，沾附在魚排上面，入鍋以橄欖油煎至熟成。', '將白花椰菜倒入攪拌機，加入月桂葉及荳蔻粉打成泥狀，並以濾網過篩致使口感綿密。', '將白花椰菜泥鋪至盤上，放上魚排，用九層塔葉擺盤裝飾即完成。']
# ----------------------------------------
# Rank: 11, Score: 0.9807000160217285
# Matched Field: ingredients
# Field Content: ['雞胸肉 300公克', '金黃蒜油 30毫升', '鮮磨黑胡椒 些許公克', '百搭香草 適量公克']
# Index ID: 107
# Name: 蒜烤香草雞
# Description: 用烤箱烘烤雞胸肉時，淋上一點蒜風味油可幫助油脂吃進雞肉裡，使肉質更軟嫩，食用時建議再搭配水煮蔬菜，是道健康無負擔的美味料理。
# Ingredients: ['雞胸肉 300公克', '金黃蒜油 30毫升', '鮮磨黑胡椒 些許公克', '百搭香草 適量公克']
# Instructions: ['於烹煮前一天，將雞胸肉淋上1大匙蒜風味油和百搭香草抓醃入味，放入冰箱隔日備用。', '料理當天，烤箱110度預熱10分鐘。', '烤箱轉至170度，將醃過的雞胸肉平鋪於烤盤上，並淋上1大匙蒜風味油。', '接著放入烤箱中，約烤10分鐘，視雞胸肉大小，烘烤過程中可測試熟成程度。', '將烤好的雞胸肉切成塊狀，撒上鮮磨黑胡椒及完成。']
# ----------------------------------------
# Rank: 12, Score: 0.9810000061988831
# Matched Field: ingredients
# Field Content: ['草蝦 300公克', '米酒 5毫升', '糖醋醬 1包', '蒜香黑胡椒 1小匙公克']
# Index ID: 787
# Name: 蒜香糖醋蝦
# Description: 中秋烤海鮮來點清爽吃法！鮮蝦以蒜香黑胡椒抓醃，撥開烤得熟透的蝦殼香氣撲鼻，再將Q彈的蝦肉沾上糖醋醬食用。果香結合蝦肉鮮甜，酸甜口感解膩開胃～
# Ingredients: ['草蝦 300公克', '米酒 5毫升', '糖醋醬 1包', '蒜香黑胡椒 1小匙公克']
# Instructions: ['食材準備', '草蝦開背去腸泥，與米酒及蒜香黑胡椒抓醃約15分鐘', '草蝦放上烤盤後烤至全熟，食用時沾糖醋醬，酸酸甜甜又微辣！']
# ----------------------------------------
# Rank: 13, Score: 0.984000027179718
# Matched Field: ingredients
# Field Content: ['蒜頭 1瓣瓣', '橄欖油 少許毫升', '小番茄 5顆', '鱸魚排 1片', '黃檸檬 1/2顆', '黑橄欖 適量顆', '酸豆 適量公克', '新鮮百里香 2-3支', '白酒 少許毫升', '玫瑰鹽 適量公克', '鮮磨黑胡椒 適量公克']
# Index ID: 253
# Name: 檸檬紙包魚(鱸魚)
# Description: 簡單蔬果食材搭配新鮮的鱸魚，透過烘烤的方式將美味全鎖在鮮嫩細緻的肉質裡。撒上黑胡椒及玫瑰鹽更帶鱸魚的鮮甜，最後添加些黃檸檬去增加清爽的口感，非常適合炎炎夏日品嚐。
# Ingredients: ['蒜頭 1瓣瓣', '橄欖油 少許毫升', '小番茄 5顆', '鱸魚排 1片', '黃檸檬 1/2顆', '黑橄欖 適量顆', '酸豆 適量公克', '新鮮百里香 2-3支', '白酒 少許毫升', '玫瑰鹽 適量公克', '鮮磨黑胡椒 適量公克']
# Instructions: ['烤箱以200度預熱，鱸魚片擦乾後兩面抹上適量黑胡椒和鹽備用', '小番茄對切，黃檸檬切薄片、大蒜切碎，另可磨一些檸檬皮屑備用', '取一張烘焙紙，將鱸魚排放在烘焙紙中央', '再放上小番茄、黑橄欖、酸豆、蒜末、百里香，淋上少許橄欖油和白酒，並放上黃檸檬片 ', '將烘焙紙上下兩端拉起往中間摺緊，並將左右兩端扭緊呈糖果狀', '將紙包魚放入烤箱中以200度考12~15分鐘即可取出，拆開紙包享用', '新鮮百里香可替換成小磨坊百里香葉']
# ----------------------------------------
# Rank: 14, Score: 0.9869999885559082
# Matched Field: ingredients
# Field Content: ['紫洋蔥 1顆', '松阪肉 240公克', '米酒 1毫升', '金黃蒜油 5毫升', '蒜香椒鹽 15公克']
# Index ID: 827
# Name: 蒜香松阪
# Description: 外層酥脆金黃，內裡豬肉鮮嫩多汁、彈牙。每一口松阪豬都均勻沾附蒜香椒鹽，香氣四溢，帶來獨特的風味層次。氣炸技術完美鎖住鮮美，豬肉的嫩滑與蒜香風味相互交織，口感層次分明。無論是單吃或搭配配菜，皆為一道極佳的佐餐佳餚，令人回味無窮。
# Ingredients: ['紫洋蔥 1顆', '松阪肉 240公克', '米酒 1毫升', '金黃蒜油 5毫升', '蒜香椒鹽 15公克']
# Instructions: ['食材準備', '松阪豬吸乾水份，切成薄片。', '將松阪豬灑上8公克蒜香椒鹽/濃蒜椒鹽、米酒抓醃，醃漬20分鐘。', '紫洋蔥切細絲。', '將松阪豬放入氣炸鍋，噴金黃蒜油，以180度5分鐘(炸熟)、200度2分鐘(上色)氣炸。(視松阪豬厚薄度調整時間)', '取出松阪豬加入紫洋蔥微拌，以180度氣炸2分鐘。', '取出後，灑上蒜香椒鹽/濃蒜椒鹽翻拌調味。']
# ----------------------------------------
# Rank: 15, Score: 0.9883999824523926
# Matched Field: instructions
# Field Content: ['首先使用米量杯裝3分滿的水倒入裝有調味粉的玻璃碗中，用湯匙均勻攪拌10秒就能輕鬆調好醬汁囉！', '接著熱油鍋，將預先準備好的洋蔥絲及辣椒放入油鍋中快速攪拌煎炸，撈起濾油備用。', '將里肌肉條與水、米酒加入玻璃深盆內，把水分打進肉裡，肉質嫩度就會更好。加入玉米粉、小磨坊鮮磨黑胡椒均勻抓醃。', '將里肌肉加入油鍋中拌炒至8分熟，拉出濾油備用。', '起熱油鍋放入洋蔥、蒜末、里肌肉、鐵板黑胡椒醬汁快速拌炒，因為肉已經經過前處理所以不需要煮太久，鍋氣中的黑胡椒香氣真的非常濃郁！起鍋前加入蔥段就可以關火盛盤。']
# Index ID: 228
# Name: 正港熱炒系列-鐵板黑胡椒
# Description: 台灣熱炒必點菜餚，特選黑胡椒、洋蔥等辛香料製作，口味辛辣，香氣四溢，適合搭配各種食材製作鐵板料理。
# Ingredients: ['洋蔥 1顆', '蒜頭 適量顆', '水 50毫升', '辣椒 適量根', '青蔥 適量根', '肉絲 300公克', '食用油 10毫升', '米酒 10毫升', '鹽 適量公克', '鮮磨黑胡椒 適量公克', '鐵板黑胡椒調味料 30公克']
# Instructions: ['首先使用米量杯裝3分滿的水倒入裝有調味粉的玻璃碗中，用湯匙均勻攪拌10秒就能輕鬆調好醬汁囉！', '接著熱油鍋，將預先準備好的洋蔥絲及辣椒放入油鍋中快速攪拌煎炸，撈起濾油備用。', '將里肌肉條與水、米酒加入玻璃深盆內，把水分打進肉裡，肉質嫩度就會更好。加入玉米粉、小磨坊鮮磨黑胡椒均勻抓醃。', '將里肌肉加入油鍋中拌炒至8分熟，拉出濾油備用。', '起熱油鍋放入洋蔥、蒜末、里肌肉、鐵板黑胡椒醬汁快速拌炒，因為肉已經經過前處理所以不需要煮太久，鍋氣中的黑胡椒香氣真的非常濃郁！起鍋前加入蔥段就可以關火盛盤。']
# ----------------------------------------
# Rank: 16, Score: 0.9891999959945679
# Matched Field: description
# Field Content: 料理新手推薦必學的一道菜，步驟簡單，零失敗率不論是悶熱的夏天或冷吱吱的冬天，都非常適合來一口
# Index ID: 160
# Name: 剝皮辣椒雞
# Description: 料理新手推薦必學的一道菜，步驟簡單，零失敗率不論是悶熱的夏天或冷吱吱的冬天，都非常適合來一口
# Ingredients: ['洋蔥 1/3顆', '青蔥 1根', '紅甜椒 1/3顆', '雞腿排 1支', '四季豆 6-8根', '剝皮辣椒 1/2罐', '米酒 15毫升', '醬油 5毫升', '金黃蒜油 25毫升', '白胡椒鹽 5公克']
# Instructions: ['去骨雞腿排切小塊，剝皮辣椒、青蔥及四季豆切小段，紅甜椒切菱形片，洋蔥切條狀', '取一玻璃器皿，放入所有食材、0.5大匙蒜風味油、白胡椒鹽、醬油膏、米酒微拌', '放入微波爐，以1000火力（W）微波4分鐘', '取出後，淋上1大匙蒜風味油微拌即完成']
# ----------------------------------------
# Rank: 17, Score: 0.9894999861717224
# Matched Field: ingredients
# Field Content: ['辣椒 1根', '草蝦 10隻公克', '高湯 100毫升', '小蘇打粉 2-3公克', '紅酒醋 15毫升', '金黃蒜油 15毫升', '紅辣椒粉 2-3公克', '玫瑰鹽 2-3公克', '鮮磨黑胡椒 2-3公克', '鮮磨白胡椒 2-3公克', '羅勒葉 2-3公克']
# Index ID: 163
# Name: 西班牙風味大蒜蝦
# Description: 充滿鮮味與蒜香味濃郁的料理，透過香氣勾起了食欲，蝦中吸附飽滿蒜風味油的香氣，一口咬下蝦子彈牙熟成程度剛好，辣椒與蒜香在嘴裡久久不散。
# Ingredients: ['辣椒 1根', '草蝦 10隻公克', '高湯 100毫升', '小蘇打粉 2-3公克', '紅酒醋 15毫升', '金黃蒜油 15毫升', '紅辣椒粉 2-3公克', '玫瑰鹽 2-3公克', '鮮磨黑胡椒 2-3公克', '鮮磨白胡椒 2-3公克', '羅勒葉 2-3公克']
# Instructions: ['蝦子去頭，開背取沙筋， 辣椒切片。', '蝦子、蒜風味油、玫瑰鹽、小蘇打粉，放入碗中拌勻。', '平底鍋熱鍋，倒入少許蒜風味油，放入蝦子拌炒，炒至蝦殼轉為鮮紅色。', '將蝦頭與雞高湯拌炒，熬出來的蝦油一起加入炒至收乾，味道會更香濃美味。', '加入雞高湯、辣椒片、黑胡椒、白胡椒 、紅辣椒粉、羅勒葉、紅酒醋，拌炒2分鐘後起鍋盛盤。']
# ----------------------------------------
# Rank: 18, Score: 0.9904999732971191
# Matched Field: description
# Field Content: 轉一轉，露營充滿儀式感！黑胡椒香氣融入椰香，麵體入口滑順、香味濃而不膩口，搭配隨手調製的調酒，既療癒又放鬆。
# Index ID: 762
# Name: 椰香辣雞肉義大利麵
# Description: 轉一轉，露營充滿儀式感！黑胡椒香氣融入椰香，麵體入口滑順、香味濃而不膩口，搭配隨手調製的調酒，既療癒又放鬆。
# Ingredients: ['洋蔥 1/4顆', '辣椒 1根', '義大利麵 1把', '雞胸肉 150公克', '冷凍花椰菜 30公克', '椰漿 350毫升', '玫瑰鹽 1/2小匙公克', '鮮磨黑胡椒 1/2小匙公克']
# Instructions: ['洋蔥切絲，辣椒切斜片，雞肉切塊', '鍋中以洋蔥鋪底，放上義大利麵、雞肉', '倒入椰漿、水約250ml，蓋蓋中小火燉煮約15分鐘', '待麵煮軟後加入冷凍花椰菜及辣椒，再拌炒煮約1分鐘後，以玫瑰鹽和黑胡椒稍做調味即可起鍋食用']
# ----------------------------------------
# Rank: 19, Score: 0.9904999732971191
# Matched Field: ingredients
# Field Content: ['雞蛋 1顆', '米飯 2碗', '紅蔥粉 少許公克', '白芝麻 7公克', '堅果 7公克', '洋香菜葉 10公克', '鮮磨黑胡椒 10公克', '義大利香料 7公克']
# Index ID: 82
# Name: 翡翠乾果炒飯
# Description: 與一般常吃的中式炒飯較不同的是，品嚐時，義大利香料遇熱釋放出的陣陣清香，讓人彷彿置身異國，雖然僅有香料與堅果拌炒，但每一口都是豐富的味覺饗宴。
# Ingredients: ['雞蛋 1顆', '米飯 2碗', '紅蔥粉 少許公克', '白芝麻 7公克', '堅果 7公克', '洋香菜葉 10公克', '鮮磨黑胡椒 10公克', '義大利香料 7公克']
# Instructions: ['蛋打散成蛋液、堅果壓碎。', '起油鍋，倒入蛋液與白飯炒至蛋液包覆米粒。', '倒入白芝麻及調味料略炒。', '加入堅果稍微拌炒即可盛盤。']
# ----------------------------------------
# Rank: 20, Score: 0.9911999702453613
# Matched Field: name
# Field Content: 香料熱紅酒
# Index ID: 194
# Name: 香料熱紅酒
# Description: 冷颼颼的冬天來杯暖呼呼的熱紅酒溫暖一下吧!*飲酒過量，有害健康**未滿十八歲禁止飲酒*
# Ingredients: ['生薑 4片公克', '蘋果 1顆', '紅酒 750毫升', '柳橙 1顆', '檸檬皮 1片', '蜂蜜 30公克', '丁香 些許公克', '肉桂粉 15公克', '八角粒 2-3個']
# Instructions: ['檸檬、柳橙各削4片皮，蘋果切片，柳橙榨汁備用', '取一鍋，分別放入檸檬皮、柳橙皮、柳橙汁、蜂蜜，小火煮滾', '倒入一半紅酒後，分別放入肉桂棒、丁香、生薑片、蘋果片，中火煮滾', '最後倒入剩下紅酒並放入八角，持續中火煮滾至微稠狀即完成', '肉桂棒可改用肉桂粉替代，蜂蜜可換成砂糖']
# ----------------------------------------

# %%
print(llm_result)
# Out:
# 推薦的料理是 **正港熱炒系列-鐵板黑胡椒**。
#
# ### 比較項目列表：
# - 米酒
# - 食用油
# - 鮮磨黑胡椒
